# %% [markdown]
# <a href="https://colab.research.google.com/github/Ovocode05/NeuroDeff/blob/main/LTNE__model_rel6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
from itertools import product
import math
import pathlib
import os
import tensorflow as tf
from typing import Dict, Tuple, List

# %%
# !pip install deepxde
# Out:
# Collecting deepxde
#   Downloading deepxde-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from deepxde) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from deepxde) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from deepxde) (1.6.1)
# Collecting scikit-optimize>=0.9.0 (from deepxde)
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from deepxde) (1.15.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.5.1)
# Collecting pyaml>=16.9 (from scikit-optimize>=0.9.0->deepxde)
#   Downloading pyaml-25.5.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize>=0.9.0->deepxde) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->deepxde) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->deepxde) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->deepxde) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->deepxde) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->deepxde) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->deepxde) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->deepxde) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->deepxde) (2.9.0.post0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.17.0)
# Downloading deepxde-1.14.0-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 5.5 MB/s eta 0:00:00
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 10.5 MB/s eta 0:00:00
# Downloading pyaml-25.5.0-py3-none-any.whl (26 kB)
# Installing collected packages: pyaml, scikit-optimize, deepxde
# Successfully installed deepxde-1.14.0 pyaml-25.5.0 scikit-optimize-0.10.2

# %%
import deepxde as dde
# Out:
# Using backend: tensorflow.compat.v1
# Other supported backends: tensorflow, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# No backend selected.
# Finding available backend...
# Found tensorflow.compat.v1
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)
# Enable just-in-time compilation with XLA.

# %%
def ode_system(n, y, config:dict) -> list:
    T_f = y[:, 0:1]
    T_s = y[:, 1:2]

    # Compute first derivatives (jacobian) - only j=0 for 1D problem
    T_f_n = dde.grad.jacobian(T_f, n)
    T_s_n = dde.grad.jacobian(T_s, n)

    # Compute second derivatives (hessian) - only j=0 for 1D problem
    T_f_nn = dde.grad.hessian(T_f, n)
    T_s_nn = dde.grad.hessian(T_s, n)

    # Dynamic parameter handling
    def get_param(name):
      val = config["physics"][name]
      if name in config["physics"]["varying_params"]:
          if callable(val):
              return val(n)  # ✅ this evaluates Bi(x)
          elif isinstance(val, (list, np.ndarray)):
              return tf.convert_to_tensor(val, dtype=n.dtype)
      return tf.convert_to_tensor(val, dtype=n.dtype)

    eps = get_param('eps')
    k = get_param('k')
    delta = get_param('delta')
    beta = get_param('beta')
    Bi = get_param('Bi')

    # Equations
    eqn1 = (eps * k * (1 + delta * T_f) * T_f_nn +
            eps * k * delta * (T_f_n**2) +
            Bi * (T_s - T_f) - 1 - beta)

    eqn2 = ((1 - eps) * (1 + delta * T_s) * T_s_nn +
            (1 - eps) * delta * (T_s_n**2) -
            Bi * (T_s - T_f) + beta)

    return [eqn1, eqn2]

# %%
# Define geometry (1D domain from 0 to 1)
geom = dde.geometry.Interval(0, 1)

# Boundary conditions
def boundary_right(x, on_boundary):
    return on_boundary and np.isclose(x[0], 1.0)

def boundary_left(x, on_boundary):
    return on_boundary and np.isclose(x[0], 0.0)

# Dirichlet BC at x=1
bc_Tf_right = dde.DirichletBC(geom, lambda x: 0, boundary_right, component=0)
bc_Ts_right = dde.DirichletBC(geom, lambda x: 0, boundary_right, component=1)

# Neumann BC at x=0
bc_Tf_left = dde.NeumannBC(geom, lambda x: 0, boundary_left, component=0)
bc_Ts_left = dde.NeumannBC(geom, lambda x: 0, boundary_left, component=1)

# %%
from deepxde.callbacks import EarlyStopping, PDEPointResampler

# %%
class PINNTrainer:
  def __init__(self, config: Dict):
    self.config = config #hyperparameters, geometry, etc

  def build_model(self, data: dde.data) -> dde.Model:
    """ Generic model builder """
    nn = dde.maps.FNN(
        [1] + [self.config["network"]["neurons"]] * self.config["network"]["layers"] + [2],
        self.config["training"]["activation"],
        "Glorot normal",
     )

    return dde.Model(data, nn)

  def train(self, model: dde.Model) -> dde.Model:
    #callbacks
    callbacks = [
       EarlyStopping(
            min_delta=1e-5,
            patience=6000,
            monitor="loss",
            start_from_epoch=1000
          ),
        PDEPointResampler(
            period=100,
            pde_points=True,
            bc_points=False
          )
      ]

    """ Generic model trainer """
    model.compile("adam", lr = self.config["training"]["lr"], loss_weights = self.config["training"]["lose_weights"])
    losshistory, train_state = model.train(iterations=self.config["training"]["epochs"], display_every = self.config["training"]["display_every"], callbacks = callbacks)


    model.compile("L-BFGS-B")
    losshistory, train_state = model.train()
    return model, losshistory, train_state

# %%
#validation
def relation_dict(n: np.ndarray) -> dict:
  RELATIONS = {
      "relation_6_a" : {
            "network": { "neurons":128, "layers":3},  # Same as before
            "training": {"activation":"swish", "lr":0.001,
                         "lose_weights": [1e3, 1e3, 1e4, 1e4, 1e2, 1e2],
                         "epochs":10000, "display_every":1000 },
            "physics": {
                "eps": 0.1,
                "k": [1,10, 20, 30, 40, 50],
                "delta": -0.2,
                "beta": 10,
                "Bi": lambda x: 50* tf.cast(1-x**2, x.dtype),
                "varying_params": ["Bi", "k"]  # Specify which params vary
            }
         },
      "relation_6_b" : {
            "network": { "neurons":256, "layers":5},  # Same as before
            "training": {"activation":"sin", "lr":0.001,
                         "lose_weights": [1e3, 1e3, 1e4, 1e4, 1e2, 1e2],
                         "epochs":10000, "display_every":1000 },
            "physics": {
                "eps": 0.1,
                "k": [1,10, 20, 30, 40, 50],
                "delta": -0.2,
                "beta": 10,
                "Bi": lambda x: 100* (tf.sin(tf.constant(2*np.pi, x.dtype) * x)**2),
                "varying_params": ["Bi", "k"]  # Specify which params vary
            }
         }
  }
  return RELATIONS

# %%
def run_relation(relation_name: str, n: np.ndarray):
        """Handles any relation from the config without deepcopy issues"""
        config = relation_dict(n)[relation_name]
        results = {}
        # Prepare parameter combinations for other relations
        varying_params = config["physics"]["varying_params"]
        param_values = [
            config["physics"][p] if isinstance(config["physics"][p], (list, np.ndarray)) else [config["physics"][p]]
            for p in varying_params
        ]

        for combo in product(*param_values):
            param_str = "_".join(f"{p}={v}" for p,v in zip(varying_params, combo))
            print(f"\nTraining {relation_name} with {param_str}")

            # Create new config without deepcopy
            current_physics = config["physics"].copy()
            for p, v in zip(varying_params, combo):
                current_physics[p] = v

            current_config = {
                "network": config["network"],
                "training": config["training"],
                "physics": current_physics
            }

            # Training setup
            ode_wrapped = lambda x, y: ode_system(x, y, current_config)
            data = dde.data.PDE(
                geom,
                ode_wrapped,
                [bc_Tf_right, bc_Ts_right, bc_Tf_left, bc_Ts_left],
                num_domain=500,
                num_boundary=20
            )

            # Build and train model
            nn = dde.maps.FNN(
                [1] + [current_config["network"]["neurons"]] * current_config["network"]["layers"] + [2],
                current_config["training"]["activation"],
                "Glorot normal"
            )
            model = dde.Model(data, nn)

            model.compile(
                "adam",
                lr=current_config["training"]["lr"],
                loss_weights=current_config["training"]["lose_weights"],
            )
            losshistory, train_state = model.train(iterations=current_config["training"]["epochs"], display_every=1000)
            model.compile("L-BFGS-B")
            losshistory, train_state = model.train()

            # Store results
            T_pred = model.predict(n)
            results[param_str] = {
                "x": n.flatten(),
                "T_f": T_pred[:, 0:1],
                "T_s": T_pred[:, 1:2],
                "params": dict(zip(varying_params, combo))
            }
            # dde.saveplot(losshistory, train_state, issave=True, isplot=True)

        return results

# %%
def plot_grouped_by_Bi(results, title_prefix="PINN Prediction Grouped by Bi"):
    """
    For each unique Bi (from result key), plot all (Tf, Ts) curves for that Bi in one figure.
    """
    import matplotlib.pyplot as plt
    from collections import defaultdict

    # Step 1: Group results by Bi
    grouped = defaultdict(dict)
    for key, res in results.items():
        # Parse key like "delta=0_Bi=<function relation_dict.<locals>.<lambda> at 0x7d98eef32b60>"
        Bi_key = [kv for kv in key.split('_') if kv.startswith("Bi=")][0]
        grouped[Bi_key][key] = res

    # Step 2: Plot each Bi group in its own figure
    for Bi_label, group in grouped.items():
        plt.figure(figsize=(10, 6))
        colors = plt.cm.tab10.colors

        for i, (label, res) in enumerate(group.items()):
            x = res["x"]
            T_f = res["T_f"].flatten()
            T_s = res["T_s"].flatten()
            color = colors[i % len(colors)]

            plt.plot(x, T_s, color=color, linestyle='-', label=f"{label} - T_s")
            plt.plot(x, T_f, color=color, linestyle='--', label=f"{label} - T_f")

        plt.xlabel("x")
        plt.ylabel("Temperature")
        plt.title(f"{title_prefix}: {Bi_label}")
        plt.legend(fontsize="small")
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# %%
n = np.linspace(0, 1, 50).reshape(-1, 1)
all_results = {}

for relation in ["relation_6_a", "relation_6_b"]:
    all_results[relation] = run_relation(relation, n)
    plot_grouped_by_Bi(all_results[relation], title_prefix=relation)
# Out:
# Training relation_6_a with Bi=<function relation_dict.<locals>.<lambda> at 0x7956896f6ca0>_k=1
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.074822 s
#
# 'compile' took 2.459564 s
#
# Training model...
#
# 0         [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    []
# 1000      [7.97e+03, 1.84e+02, 8.20e+02, 8.65e+02, 3.31e+01, 2.58e+01]    [7.97e+03, 1.84e+02, 8.20e+02, 8.65e+02, 3.31e+01, 2.58e+01]    []
# 2000      [2.58e+01, 4.90e+00, 1.64e-01, 4.71e-01, 4.31e+00, 5.87e+00]    [2.58e+01, 4.90e+00, 1.64e-01, 4.71e-01, 4.31e+00, 5.87e+00]    []
# 3000      [2.02e+01, 2.95e+00, 1.46e-01, 1.37e-01, 3.92e-01, 2.91e-01]    [2.02e+01, 2.95e+00, 1.46e-01, 1.37e-01, 3.92e-01, 2.91e-01]    []
# 4000      [5.38e+01, 4.91e+01, 2.30e-01, 2.00e-02, 5.76e-01, 2.04e-02]    [5.38e+01, 4.91e+01, 2.30e-01, 2.00e-02, 5.76e-01, 2.04e-02]    []
# 5000      [1.14e+01, 2.15e+00, 1.07e-02, 1.71e-02, 3.49e-01, 8.26e-02]    [1.14e+01, 2.15e+00, 1.07e-02, 1.71e-02, 3.49e-01, 8.26e-02]    []
# 6000      [9.10e+00, 1.65e+00, 2.33e-02, 1.27e-02, 4.11e-01, 1.43e-01]    [9.10e+00, 1.65e+00, 2.33e-02, 1.27e-02, 4.11e-01, 1.43e-01]    []
# 7000      [7.91e+00, 1.56e+00, 1.70e-02, 8.25e-03, 3.60e-01, 1.54e-01]    [7.91e+00, 1.56e+00, 1.70e-02, 8.25e-03, 3.60e-01, 1.54e-01]    []
# 8000      [7.01e+00, 1.43e+00, 1.27e-02, 4.49e-03, 2.59e-01, 1.71e-01]    [7.01e+00, 1.43e+00, 1.27e-02, 4.49e-03, 2.59e-01, 1.71e-01]    []
# 9000      [6.31e+00, 1.30e+00, 1.05e-02, 1.24e-02, 5.28e-01, 7.62e-02]    [6.31e+00, 1.30e+00, 1.05e-02, 1.24e-02, 5.28e-01, 7.62e-02]    []
# 10000     [2.87e+01, 2.82e+01, 8.68e-01, 9.66e-03, 9.90e-01, 3.64e-02]    [2.87e+01, 2.82e+01, 8.68e-01, 9.66e-03, 9.90e-01, 3.64e-02]    []
#
# Best model at step 9000:
#   train loss: 8.24e+00
#   test loss: 8.24e+00
#   test metric: []
#
# 'train' took 24.800901 s
#
# Compiling model...
# 'compile' took 2.133226 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [2.87e-02, 2.82e-02, 8.68e-05, 9.66e-07, 9.90e-03, 3.64e-04]    [2.87e-02, 2.82e-02, 8.68e-05, 9.66e-07, 9.90e-03, 3.64e-04]    []
# 10016     [2.87e-02, 2.82e-02, 8.68e-05, 9.66e-07, 9.90e-03, 3.64e-04]    [2.87e-02, 2.82e-02, 8.68e-05, 9.66e-07, 9.90e-03, 3.64e-04]    []
#
# Best model at step 10000:
#   train loss: 6.72e-02
#   test loss: 6.72e-02
#   test metric: []
#
# 'train' took 9.319143 s
#
#
# Training relation_6_a with Bi=<function relation_dict.<locals>.<lambda> at 0x7956896f6ca0>_k=10
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.064644 s
#
# 'compile' took 3.264842 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    []
# 1000      [5.47e+00, 1.25e+01, 1.48e-01, 3.50e-01, 2.80e+00, 1.12e-01]    [5.47e+00, 1.25e+01, 1.48e-01, 3.50e-01, 2.80e+00, 1.12e-01]    []
# 2000      [5.05e+00, 9.68e+00, 1.31e-01, 1.64e-01, 8.74e-01, 4.26e-02]    [5.05e+00, 9.68e+00, 1.31e-01, 1.64e-01, 8.74e-01, 4.26e-02]    []
# 3000      [4.27e+00, 8.27e+00, 1.00e-01, 1.14e-01, 6.04e-01, 1.43e-01]    [4.27e+00, 8.27e+00, 1.00e-01, 1.14e-01, 6.04e-01, 1.43e-01]    []
# 4000      [3.55e+00, 6.82e+00, 7.31e-02, 7.23e-02, 4.08e-01, 2.11e-01]    [3.55e+00, 6.82e+00, 7.31e-02, 7.23e-02, 4.08e-01, 2.11e-01]    []
# 5000      [2.84e+00, 5.54e+00, 4.77e-02, 4.81e-02, 3.61e-01, 2.06e-01]    [2.84e+00, 5.54e+00, 4.77e-02, 4.81e-02, 3.61e-01, 2.06e-01]    []
# 6000      [2.33e+00, 4.59e+00, 3.02e-02, 3.32e-02, 3.24e-01, 1.79e-01]    [2.33e+00, 4.59e+00, 3.02e-02, 3.32e-02, 3.24e-01, 1.79e-01]    []
# 7000      [8.03e+00, 1.01e+01, 1.38e-04, 4.26e-04, 2.86e-01, 1.51e-01]    [8.03e+00, 1.01e+01, 1.38e-04, 4.26e-04, 2.86e-01, 1.51e-01]    []
# 8000      [4.63e+00, 6.38e+00, 2.15e-04, 3.77e-03, 2.16e-01, 1.19e-01]    [4.63e+00, 6.38e+00, 2.15e-04, 3.77e-03, 2.16e-01, 1.19e-01]    []
# 9000      [1.77e+00, 3.27e+00, 1.03e-02, 2.02e-02, 2.00e-01, 1.00e-01]    [1.77e+00, 3.27e+00, 1.03e-02, 2.02e-02, 2.00e-01, 1.00e-01]    []
# 10000     [1.61e+00, 2.93e+00, 3.19e-03, 1.58e-02, 2.30e-01, 5.57e-02]    [1.61e+00, 2.93e+00, 3.19e-03, 1.58e-02, 2.30e-01, 5.57e-02]    []
#
# Best model at step 10000:
#   train loss: 4.84e+00
#   test loss: 4.84e+00
#   test metric: []
#
# 'train' took 25.923149 s
#
# Compiling model...
# 'compile' took 2.599238 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [1.61e-03, 2.93e-03, 3.19e-07, 1.58e-06, 2.30e-03, 5.57e-04]    [1.61e-03, 2.93e-03, 3.19e-07, 1.58e-06, 2.30e-03, 5.57e-04]    []
# 10019     [1.61e-03, 2.93e-03, 3.19e-07, 1.58e-06, 2.30e-03, 5.57e-04]    [1.61e-03, 2.93e-03, 3.19e-07, 1.58e-06, 2.30e-03, 5.57e-04]    []
#
# Best model at step 10000:
#   train loss: 7.40e-03
#   test loss: 7.40e-03
#   test metric: []
#
# 'train' took 11.021592 s
#
#
# Training relation_6_a with Bi=<function relation_dict.<locals>.<lambda> at 0x7956896f6ca0>_k=20
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.062499 s
#
# 'compile' took 2.632926 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    []
# 1000      [1.09e+01, 2.34e+01, 8.59e-01, 8.38e-01, 8.79e-01, 1.67e-01]    [1.09e+01, 2.34e+01, 8.59e-01, 8.38e-01, 8.79e-01, 1.67e-01]    []
# 2000      [4.55e+00, 1.27e+01, 3.58e-01, 4.10e-01, 7.37e-03, 2.63e-02]    [4.55e+00, 1.27e+01, 3.58e-01, 4.10e-01, 7.37e-03, 2.63e-02]    []
# 3000      [3.63e+00, 9.11e+00, 1.53e-01, 1.68e-01, 9.94e-03, 1.91e-02]    [3.63e+00, 9.11e+00, 1.53e-01, 1.68e-01, 9.94e-03, 1.91e-02]    []
# 4000      [3.12e+00, 7.71e+00, 1.01e-01, 1.08e-01, 4.24e-03, 1.48e-02]    [3.12e+00, 7.71e+00, 1.01e-01, 1.08e-01, 4.24e-03, 1.48e-02]    []
# 5000      [2.66e+00, 6.67e+00, 7.87e-02, 8.68e-02, 3.45e-05, 8.04e-03]    [2.66e+00, 6.67e+00, 7.87e-02, 8.68e-02, 3.45e-05, 8.04e-03]    []
# 6000      [2.23e+00, 5.69e+00, 8.24e-02, 8.15e-02, 2.30e-03, 8.40e-04]    [2.23e+00, 5.69e+00, 8.24e-02, 8.15e-02, 2.30e-03, 8.40e-04]    []
# 7000      [2.08e+00, 5.06e+00, 2.30e-02, 4.45e-02, 6.44e-03, 2.49e-03]    [2.08e+00, 5.06e+00, 2.30e-02, 4.45e-02, 6.44e-03, 2.49e-03]    []
# 8000      [1.43e+00, 3.87e+00, 2.33e-02, 3.26e-02, 2.38e-02, 2.09e-02]    [1.43e+00, 3.87e+00, 2.33e-02, 3.26e-02, 2.38e-02, 2.09e-02]    []
# 9000      [2.28e+00, 4.21e+00, 5.93e-04, 6.18e-03, 5.20e-02, 5.23e-02]    [2.28e+00, 4.21e+00, 5.93e-04, 6.18e-03, 5.20e-02, 5.23e-02]    []
# 10000     [9.31e-01, 2.66e+00, 1.56e-02, 1.74e-02, 7.21e-02, 9.52e-02]    [9.31e-01, 2.66e+00, 1.56e-02, 1.74e-02, 7.21e-02, 9.52e-02]    []
#
# Best model at step 10000:
#   train loss: 3.79e+00
#   test loss: 3.79e+00
#   test metric: []
#
# 'train' took 25.688575 s
#
# Compiling model...
# 'compile' took 2.330039 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [9.31e-04, 2.66e-03, 1.56e-06, 1.74e-06, 7.21e-04, 9.52e-04]    [9.31e-04, 2.66e-03, 1.56e-06, 1.74e-06, 7.21e-04, 9.52e-04]    []
# 10018     [9.31e-04, 2.66e-03, 1.56e-06, 1.74e-06, 7.21e-04, 9.52e-04]    [9.31e-04, 2.66e-03, 1.56e-06, 1.74e-06, 7.21e-04, 9.52e-04]    []
#
# Best model at step 10000:
#   train loss: 5.27e-03
#   test loss: 5.27e-03
#   test metric: []
#
# 'train' took 11.578282 s
#
#
# Training relation_6_a with Bi=<function relation_dict.<locals>.<lambda> at 0x7956896f6ca0>_k=30
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.062163 s
#
# 'compile' took 2.696324 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    []
# 1000      [9.35e+00, 8.16e+01, 6.53e+00, 4.10e+00, 1.44e+00, 1.08e+01]    [9.35e+00, 8.16e+01, 6.53e+00, 4.10e+00, 1.44e+00, 1.08e+01]    []
# 2000      [6.19e+00, 5.94e+01, 1.94e+00, 1.55e+00, 6.45e-02, 1.60e+00]    [6.19e+00, 5.94e+01, 1.94e+00, 1.55e+00, 6.45e-02, 1.60e+00]    []
# 3000      [5.69e+00, 3.75e+01, 4.53e-01, 3.92e-01, 1.79e-01, 5.39e-01]    [5.69e+00, 3.75e+01, 4.53e-01, 3.92e-01, 1.79e-01, 5.39e-01]    []
# 4000      [1.82e+01, 3.36e+01, 7.63e-01, 4.78e-01, 1.02e-01, 2.26e-01]    [1.82e+01, 3.36e+01, 7.63e-01, 4.78e-01, 1.02e-01, 2.26e-01]    []
# 5000      [4.75e-01, 7.72e+00, 9.33e-02, 8.64e-02, 3.06e-02, 7.19e-02]    [4.75e-01, 7.72e+00, 9.33e-02, 8.64e-02, 3.06e-02, 7.19e-02]    []
# 6000      [6.28e-01, 5.01e+00, 4.15e-02, 4.20e-02, 4.77e-02, 3.83e-02]    [6.28e-01, 5.01e+00, 4.15e-02, 4.20e-02, 4.77e-02, 3.83e-02]    []
# 7000      [5.17e-01, 3.58e+00, 2.80e-02, 2.11e-02, 5.68e-02, 3.56e-02]    [5.17e-01, 3.58e+00, 2.80e-02, 2.11e-02, 5.68e-02, 3.56e-02]    []
# 8000      [6.46e+01, 5.60e+01, 4.67e-01, 1.50e-01, 3.02e-02, 2.43e-02]    [6.46e+01, 5.60e+01, 4.67e-01, 1.50e-01, 3.02e-02, 2.43e-02]    []
# 9000      [3.59e+01, 2.28e+01, 1.22e-01, 2.86e-02, 3.58e-02, 2.27e-02]    [3.59e+01, 2.28e+01, 1.22e-01, 2.86e-02, 3.58e-02, 2.27e-02]    []
# 10000     [2.77e-01, 1.40e+00, 5.48e-03, 4.80e-03, 3.63e-02, 4.66e-02]    [2.77e-01, 1.40e+00, 5.48e-03, 4.80e-03, 3.63e-02, 4.66e-02]    []
#
# Best model at step 10000:
#   train loss: 1.77e+00
#   test loss: 1.77e+00
#   test metric: []
#
# 'train' took 26.347919 s
#
# Compiling model...
# 'compile' took 2.427741 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [2.77e-04, 1.40e-03, 5.48e-07, 4.80e-07, 3.63e-04, 4.66e-04]    [2.77e-04, 1.40e-03, 5.48e-07, 4.80e-07, 3.63e-04, 4.66e-04]    []
# 10017     [2.77e-04, 1.40e-03, 5.48e-07, 4.80e-07, 3.63e-04, 4.66e-04]    [2.77e-04, 1.40e-03, 5.48e-07, 4.80e-07, 3.63e-04, 4.66e-04]    []
#
# Best model at step 10000:
#   train loss: 2.50e-03
#   test loss: 2.50e-03
#   test metric: []
#
# 'train' took 12.458563 s
#
#
# Training relation_6_a with Bi=<function relation_dict.<locals>.<lambda> at 0x7956896f6ca0>_k=40
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.063069 s
#
# 'compile' took 2.714823 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    []
# 1000      [1.37e+01, 2.36e+01, 4.65e-01, 4.06e-01, 1.03e+00, 6.14e-01]    [1.37e+01, 2.36e+01, 4.65e-01, 4.06e-01, 1.03e+00, 6.14e-01]    []
# 2000      [4.74e+00, 1.47e+01, 5.74e-01, 5.16e-01, 1.58e-01, 2.57e-05]    [4.74e+00, 1.47e+01, 5.74e-01, 5.16e-01, 1.58e-01, 2.57e-05]    []
# 3000      [3.73e+00, 1.22e+01, 3.08e-01, 3.17e-01, 3.08e-02, 8.62e-02]    [3.73e+00, 1.22e+01, 3.08e-01, 3.17e-01, 3.08e-02, 8.62e-02]    []
# 4000      [2.97e+00, 1.08e+01, 2.04e-01, 2.18e-01, 1.75e-02, 1.02e-01]    [2.97e+00, 1.08e+01, 2.04e-01, 2.18e-01, 1.75e-02, 1.02e-01]    []
# 5000      [2.26e+00, 9.64e+00, 1.53e-01, 1.66e-01, 8.58e-03, 7.47e-02]    [2.26e+00, 9.64e+00, 1.53e-01, 1.66e-01, 8.58e-03, 7.47e-02]    []
# 6000      [1.66e+00, 8.49e+00, 1.14e-01, 1.24e-01, 2.41e-03, 4.33e-02]    [1.66e+00, 8.49e+00, 1.14e-01, 1.24e-01, 2.41e-03, 4.33e-02]    []
# 7000      [1.23e+00, 7.23e+00, 8.28e-02, 8.78e-02, 4.75e-05, 1.56e-02]    [1.23e+00, 7.23e+00, 8.28e-02, 8.78e-02, 4.75e-05, 1.56e-02]    []
# 8000      [9.42e-01, 5.92e+00, 5.99e-02, 6.23e-02, 4.34e-03, 5.93e-04]    [9.42e-01, 5.92e+00, 5.99e-02, 6.23e-02, 4.34e-03, 5.93e-04]    []
# 9000      [7.13e-01, 4.58e+00, 3.83e-02, 4.54e-02, 3.14e-02, 9.74e-03]    [7.13e-01, 4.58e+00, 3.83e-02, 4.54e-02, 3.14e-02, 9.74e-03]    []
# 10000     [3.49e+00, 4.84e+00, 2.64e-04, 7.40e-03, 7.56e-02, 6.37e-02]    [3.49e+00, 4.84e+00, 2.64e-04, 7.40e-03, 7.56e-02, 6.37e-02]    []
#
# Best model at step 9000:
#   train loss: 5.42e+00
#   test loss: 5.42e+00
#   test metric: []
#
# 'train' took 26.231770 s
#
# Compiling model...
# 'compile' took 4.083806 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [3.49e-03, 4.84e-03, 2.64e-08, 7.40e-07, 7.56e-04, 6.37e-04]    [3.49e-03, 4.84e-03, 2.64e-08, 7.40e-07, 7.56e-04, 6.37e-04]    []
# 10017     [3.49e-03, 4.84e-03, 2.64e-08, 7.40e-07, 7.56e-04, 6.37e-04]    [3.49e-03, 4.84e-03, 2.64e-08, 7.40e-07, 7.56e-04, 6.37e-04]    []
#
# Best model at step 10000:
#   train loss: 9.73e-03
#   test loss: 9.73e-03
#   test metric: []
#
# 'train' took 13.885282 s
#
#
# Training relation_6_a with Bi=<function relation_dict.<locals>.<lambda> at 0x7956896f6ca0>_k=50
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.075191 s
#
# 'compile' took 2.811541 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    [1.16e+05, 9.54e+04, 2.07e+00, 8.85e-02, 2.34e-02, 2.89e-03]    []
# 1000      [9.32e+01, 1.99e+02, 1.27e+00, 1.05e-01, 2.99e-01, 2.84e-01]    [9.32e+01, 1.99e+02, 1.27e+00, 1.05e-01, 2.99e-01, 2.84e-01]    []
# 2000      [7.24e+00, 5.21e+01, 1.67e+00, 1.26e+00, 2.59e-03, 1.25e-04]    [7.24e+00, 5.21e+01, 1.67e+00, 1.26e+00, 2.59e-03, 1.25e-04]    []
# 3000      [1.60e+01, 3.22e+01, 3.44e-02, 2.68e-02, 1.35e-02, 1.27e-01]    [1.60e+01, 3.22e+01, 3.44e-02, 2.68e-02, 1.35e-02, 1.27e-01]    []
# 4000      [2.45e+00, 1.18e+01, 2.15e-01, 1.75e-01, 3.69e-03, 1.72e-01]    [2.45e+00, 1.18e+01, 2.15e-01, 1.75e-01, 3.69e-03, 1.72e-01]    []
# 5000      [8.36e-01, 5.49e+00, 8.72e-02, 6.54e-02, 1.15e-04, 1.19e-01]    [8.36e-01, 5.49e+00, 8.72e-02, 6.54e-02, 1.15e-04, 1.19e-01]    []
# 6000      [1.05e+00, 3.22e+00, 5.39e-02, 4.50e-02, 4.42e-03, 3.63e-02]    [1.05e+00, 3.22e+00, 5.39e-02, 4.50e-02, 4.42e-03, 3.63e-02]    []
# 7000      [1.35e+02, 5.08e+01, 9.96e-01, 7.02e-03, 9.29e-04, 3.09e-02]    [1.35e+02, 5.08e+01, 9.96e-01, 7.02e-03, 9.29e-04, 3.09e-02]    []
# 8000      [8.89e-01, 1.65e+00, 1.54e-02, 1.37e-02, 9.70e-04, 1.06e-02]    [8.89e-01, 1.65e+00, 1.54e-02, 1.37e-02, 9.70e-04, 1.06e-02]    []
# 9000      [7.44e-01, 1.44e+00, 1.18e-02, 1.06e-02, 5.85e-04, 8.71e-03]    [7.44e-01, 1.44e+00, 1.18e-02, 1.06e-02, 5.85e-04, 8.71e-03]    []
# 10000     [4.85e+00, 3.26e+00, 2.77e-01, 1.54e-01, 1.74e-05, 2.80e-02]    [4.85e+00, 3.26e+00, 2.77e-01, 1.54e-01, 1.74e-05, 2.80e-02]    []
#
# Best model at step 9000:
#   train loss: 2.22e+00
#   test loss: 2.22e+00
#   test metric: []
#
# 'train' took 27.308446 s
#
# Compiling model...
# 'compile' took 3.265409 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [4.85e-03, 3.26e-03, 2.77e-05, 1.54e-05, 1.74e-07, 2.80e-04]    [4.85e-03, 3.26e-03, 2.77e-05, 1.54e-05, 1.74e-07, 2.80e-04]    []
# 10016     [4.85e-03, 3.26e-03, 2.77e-05, 1.54e-05, 1.74e-07, 2.80e-04]    [4.85e-03, 3.26e-03, 2.77e-05, 1.54e-05, 1.74e-07, 2.80e-04]    []
#
# Best model at step 10000:
#   train loss: 8.43e-03
#   test loss: 8.43e-03
#   test metric: []
#
# 'train' took 14.657993 s
# Training relation_6_b with Bi=<function relation_dict.<locals>.<lambda> at 0x79566aa2c040>_k=1
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.069429 s
#
# 'compile' took 2.830556 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    []
# 1000      [2.60e+04, 2.92e+03, 9.31e+01, 1.87e+02, 1.52e+02, 3.15e+01]    [2.60e+04, 2.92e+03, 9.31e+01, 1.87e+02, 1.52e+02, 3.15e+01]    []
# 2000      [3.74e+02, 3.22e+01, 4.86e-01, 4.01e-01, 4.03e+01, 2.48e+02]    [3.74e+02, 3.22e+01, 4.86e-01, 4.01e-01, 4.03e+01, 2.48e+02]    []
# 3000      [1.31e+02, 4.68e+01, 4.36e-02, 3.17e-01, 1.21e+00, 2.50e+01]    [1.31e+02, 4.68e+01, 4.36e-02, 3.17e-01, 1.21e+00, 2.50e+01]    []
# 4000      [6.82e+01, 3.43e+01, 2.20e-03, 1.94e-01, 4.83e-01, 4.91e+00]    [6.82e+01, 3.43e+01, 2.20e-03, 1.94e-01, 4.83e-01, 4.91e+00]    []
# 5000      [3.30e+01, 1.64e+01, 3.23e-02, 1.30e-01, 1.15e-01, 9.23e-01]    [3.30e+01, 1.64e+01, 3.23e-02, 1.30e-01, 1.15e-01, 9.23e-01]    []
# 6000      [1.53e+01, 5.02e+00, 1.24e-02, 2.19e-02, 2.36e-02, 5.93e-02]    [1.53e+01, 5.02e+00, 1.24e-02, 2.19e-02, 2.36e-02, 5.93e-02]    []
# 7000      [1.47e+01, 1.32e+01, 2.07e+00, 1.00e-01, 2.07e-01, 1.06e-04]    [1.47e+01, 1.32e+01, 2.07e+00, 1.00e-01, 2.07e-01, 1.06e-04]    []
# 8000      [5.02e+00, 2.91e-01, 4.42e-04, 6.12e-04, 1.15e-03, 1.26e-02]    [5.02e+00, 2.91e-01, 4.42e-04, 6.12e-04, 1.15e-03, 1.26e-02]    []
# 9000      [3.99e+00, 3.26e-01, 2.56e-05, 2.01e-03, 1.42e-03, 5.29e-02]    [3.99e+00, 3.26e-01, 2.56e-05, 2.01e-03, 1.42e-03, 5.29e-02]    []
# 10000     [3.23e+00, 3.81e-01, 2.51e-03, 1.09e-03, 4.36e-04, 9.89e-03]    [3.23e+00, 3.81e-01, 2.51e-03, 1.09e-03, 4.36e-04, 9.89e-03]    []
#
# Best model at step 10000:
#   train loss: 3.63e+00
#   test loss: 3.63e+00
#   test metric: []
#
# 'train' took 40.125108 s
#
# Compiling model...
# 'compile' took 2.918360 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [3.23e-03, 3.81e-04, 2.51e-07, 1.09e-07, 4.36e-06, 9.89e-05]    [3.23e-03, 3.81e-04, 2.51e-07, 1.09e-07, 4.36e-06, 9.89e-05]    []
# 10018     [3.23e-03, 3.81e-04, 2.51e-07, 1.09e-07, 4.36e-06, 9.89e-05]    [3.23e-03, 3.81e-04, 2.51e-07, 1.09e-07, 4.36e-06, 9.89e-05]    []
#
# Best model at step 10000:
#   train loss: 3.71e-03
#   test loss: 3.71e-03
#   test metric: []
#
# 'train' took 15.793208 s
#
#
# Training relation_6_b with Bi=<function relation_dict.<locals>.<lambda> at 0x79566aa2c040>_k=10
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.064458 s
#
# 'compile' took 2.933286 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    []
# 1000      [7.16e+02, 9.41e+02, 3.63e+01, 9.66e+01, 1.70e+02, 4.20e+02]    [7.16e+02, 9.41e+02, 3.63e+01, 9.66e+01, 1.70e+02, 4.20e+02]    []
# 2000      [5.22e+02, 7.77e+02, 9.26e+00, 2.39e+01, 4.12e+01, 4.58e+02]    [5.22e+02, 7.77e+02, 9.26e+00, 2.39e+01, 4.12e+01, 4.58e+02]    []
# 3000      [2.57e+02, 4.83e+02, 1.21e+01, 2.52e+01, 5.40e+01, 3.82e+02]    [2.57e+02, 4.83e+02, 1.21e+01, 2.52e+01, 5.40e+01, 3.82e+02]    []
# 4000      [1.83e+01, 2.49e+01, 8.04e-01, 1.15e-01, 3.61e-01, 2.62e+01]    [1.83e+01, 2.49e+01, 8.04e-01, 1.15e-01, 3.61e-01, 2.62e+01]    []
# 5000      [1.70e+01, 1.80e+01, 3.63e-01, 1.76e-01, 1.02e-02, 5.08e-01]    [1.70e+01, 1.80e+01, 3.63e-01, 1.76e-01, 1.02e-02, 5.08e-01]    []
# 6000      [1.64e+01, 1.56e+01, 3.17e-01, 1.91e-01, 3.25e-02, 1.57e-01]    [1.64e+01, 1.56e+01, 3.17e-01, 1.91e-01, 3.25e-02, 1.57e-01]    []
# 7000      [1.66e+01, 1.74e+01, 2.22e-01, 1.49e-01, 2.72e-01, 3.88e-01]    [1.66e+01, 1.74e+01, 2.22e-01, 1.49e-01, 2.72e-01, 3.88e-01]    []
# 8000      [1.49e+01, 1.29e+01, 1.93e-01, 1.38e-01, 5.05e-02, 5.85e-02]    [1.49e+01, 1.29e+01, 1.93e-01, 1.38e-01, 5.05e-02, 5.85e-02]    []
# 9000      [1.25e+01, 1.03e+01, 1.33e-01, 8.67e-02, 1.97e-02, 1.48e-02]    [1.25e+01, 1.03e+01, 1.33e-01, 8.67e-02, 1.97e-02, 1.48e-02]    []
# 10000     [1.04e+01, 8.51e+00, 9.72e-02, 5.97e-02, 2.20e-02, 1.04e-02]    [1.04e+01, 8.51e+00, 9.72e-02, 5.97e-02, 2.20e-02, 1.04e-02]    []
#
# Best model at step 10000:
#   train loss: 1.91e+01
#   test loss: 1.91e+01
#   test metric: []
#
# 'train' took 39.679556 s
#
# Compiling model...
# 'compile' took 2.761448 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [1.04e-02, 8.51e-03, 9.72e-06, 5.97e-06, 2.20e-04, 1.04e-04]    [1.04e-02, 8.51e-03, 9.72e-06, 5.97e-06, 2.20e-04, 1.04e-04]    []
# 10017     [1.04e-02, 8.51e-03, 9.72e-06, 5.97e-06, 2.20e-04, 1.04e-04]    [1.04e-02, 8.51e-03, 9.72e-06, 5.97e-06, 2.20e-04, 1.04e-04]    []
#
# Best model at step 10000:
#   train loss: 1.93e-02
#   test loss: 1.93e-02
#   test metric: []
#
# 'train' took 16.698554 s
#
#
# Training relation_6_b with Bi=<function relation_dict.<locals>.<lambda> at 0x79566aa2c040>_k=20
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.091632 s
#
# 'compile' took 3.142270 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    []
# 1000      [5.87e+02, 7.66e+02, 3.63e+01, 3.62e+01, 4.84e+01, 4.27e+02]    [5.87e+02, 7.66e+02, 3.63e+01, 3.62e+01, 4.84e+01, 4.27e+02]    []
# 2000      [4.15e+02, 6.31e+02, 5.72e+00, 2.01e+01, 2.06e+01, 3.72e+02]    [4.15e+02, 6.31e+02, 5.72e+00, 2.01e+01, 2.06e+01, 3.72e+02]    []
# 3000      [1.92e+02, 4.02e+02, 5.94e+00, 1.86e+01, 2.34e+01, 3.21e+02]    [1.92e+02, 4.02e+02, 5.94e+00, 1.86e+01, 2.34e+01, 3.21e+02]    []
# 4000      [5.09e+01, 7.23e+01, 1.86e-01, 2.17e-01, 1.18e+01, 1.09e+02]    [5.09e+01, 7.23e+01, 1.86e-01, 2.17e-01, 1.18e+01, 1.09e+02]    []
# 5000      [2.62e+01, 1.16e+01, 7.94e-01, 4.41e-01, 1.31e-01, 4.14e+00]    [2.62e+01, 1.16e+01, 7.94e-01, 4.41e-01, 1.31e-01, 4.14e+00]    []
# 6000      [1.15e+01, 5.94e+00, 2.05e-01, 1.55e-01, 9.25e-02, 5.37e-01]    [1.15e+01, 5.94e+00, 2.05e-01, 1.55e-01, 9.25e-02, 5.37e-01]    []
# 7000      [7.13e+00, 4.52e+00, 4.53e-02, 2.06e-02, 1.60e-01, 4.14e-01]    [7.13e+00, 4.52e+00, 4.53e-02, 2.06e-02, 1.60e-01, 4.14e-01]    []
# 8000      [2.00e+01, 1.63e+01, 8.99e-03, 2.49e-03, 3.48e-01, 1.38e+00]    [2.00e+01, 1.63e+01, 8.99e-03, 2.49e-03, 3.48e-01, 1.38e+00]    []
# 9000      [1.55e+01, 1.33e+01, 8.99e-02, 3.36e-02, 1.50e-01, 2.70e-01]    [1.55e+01, 1.33e+01, 8.99e-02, 3.36e-02, 1.50e-01, 2.70e-01]    []
# 10000     [3.59e+00, 2.31e+00, 5.91e-03, 5.46e-03, 1.93e-01, 1.65e-01]    [3.59e+00, 2.31e+00, 5.91e-03, 5.46e-03, 1.93e-01, 1.65e-01]    []
#
# Best model at step 10000:
#   train loss: 6.27e+00
#   test loss: 6.27e+00
#   test metric: []
#
# 'train' took 40.325937 s
#
# Compiling model...
# 'compile' took 5.037107 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [3.59e-03, 2.31e-03, 5.91e-07, 5.46e-07, 1.93e-03, 1.65e-03]    [3.59e-03, 2.31e-03, 5.91e-07, 5.46e-07, 1.93e-03, 1.65e-03]    []
# 10018     [3.59e-03, 2.31e-03, 5.91e-07, 5.46e-07, 1.93e-03, 1.65e-03]    [3.59e-03, 2.31e-03, 5.91e-07, 5.46e-07, 1.93e-03, 1.65e-03]    []
#
# Best model at step 10000:
#   train loss: 9.48e-03
#   test loss: 9.48e-03
#   test metric: []
#
# 'train' took 18.877705 s
#
#
# Training relation_6_b with Bi=<function relation_dict.<locals>.<lambda> at 0x79566aa2c040>_k=30
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.073953 s
#
# 'compile' took 3.857129 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    []
# 1000      [5.12e+02, 7.07e+02, 4.08e+01, 7.77e+01, 2.83e+01, 3.87e+02]    [5.12e+02, 7.07e+02, 4.08e+01, 7.77e+01, 2.83e+01, 3.87e+02]    []
# 2000      [4.07e+02, 6.10e+02, 6.18e+00, 2.13e+01, 1.41e+01, 3.49e+02]    [4.07e+02, 6.10e+02, 6.18e+00, 2.13e+01, 1.41e+01, 3.49e+02]    []
# 3000      [2.37e+02, 4.72e+02, 5.96e+00, 1.90e+01, 1.63e+01, 3.15e+02]    [2.37e+02, 4.72e+02, 5.96e+00, 1.90e+01, 1.63e+01, 3.15e+02]    []
# 4000      [5.19e+01, 1.47e+02, 3.16e-01, 1.99e+00, 1.49e+01, 1.67e+02]    [5.19e+01, 1.47e+02, 3.16e-01, 1.99e+00, 1.49e+01, 1.67e+02]    []
# 5000      [5.03e+01, 4.46e+01, 2.52e-02, 1.04e-01, 5.20e+00, 3.43e+01]    [5.03e+01, 4.46e+01, 2.52e-02, 1.04e-01, 5.20e+00, 3.43e+01]    []
# 6000      [1.30e+02, 1.28e+02, 6.51e-04, 3.38e-01, 5.71e-01, 1.02e-01]    [1.30e+02, 1.28e+02, 6.51e-04, 3.38e-01, 5.71e-01, 1.02e-01]    []
# 7000      [3.83e+00, 6.74e+00, 5.38e-02, 5.99e-02, 4.22e-02, 7.43e-02]    [3.83e+00, 6.74e+00, 5.38e-02, 5.99e-02, 4.22e-02, 7.43e-02]    []
# 8000      [1.54e+00, 3.00e+00, 1.35e-02, 1.61e-02, 6.46e-03, 1.40e-03]    [1.54e+00, 3.00e+00, 1.35e-02, 1.61e-02, 6.46e-03, 1.40e-03]    []
# 9000      [1.42e+00, 2.23e+00, 5.64e-03, 6.22e-03, 3.27e-04, 2.62e-04]    [1.42e+00, 2.23e+00, 5.64e-03, 6.22e-03, 3.27e-04, 2.62e-04]    []
# 10000     [6.42e+00, 6.54e+00, 1.92e-03, 5.64e-03, 1.71e-02, 1.63e-01]    [6.42e+00, 6.54e+00, 1.92e-03, 5.64e-03, 1.71e-02, 1.63e-01]    []
#
# Best model at step 9000:
#   train loss: 3.66e+00
#   test loss: 3.66e+00
#   test metric: []
#
# 'train' took 41.781008 s
#
# Compiling model...
# 'compile' took 3.018673 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [6.42e-03, 6.54e-03, 1.92e-07, 5.64e-07, 1.71e-04, 1.63e-03]    [6.42e-03, 6.54e-03, 1.92e-07, 5.64e-07, 1.71e-04, 1.63e-03]    []
# 10018     [6.42e-03, 6.54e-03, 1.92e-07, 5.64e-07, 1.71e-04, 1.63e-03]    [6.42e-03, 6.54e-03, 1.92e-07, 5.64e-07, 1.71e-04, 1.63e-03]    []
#
# Best model at step 10000:
#   train loss: 1.48e-02
#   test loss: 1.48e-02
#   test metric: []
#
# 'train' took 20.818024 s
#
#
# Training relation_6_b with Bi=<function relation_dict.<locals>.<lambda> at 0x79566aa2c040>_k=40
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.062586 s
#
# 'compile' took 3.809556 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    []
# 1000      [3.95e+02, 6.09e+02, 1.20e+01, 3.46e+01, 2.11e+01, 3.84e+02]    [3.95e+02, 6.09e+02, 1.20e+01, 3.46e+01, 2.11e+01, 3.84e+02]    []
# 2000      [3.08e+02, 5.67e+02, 5.37e+00, 1.98e+01, 1.18e+01, 3.18e+02]    [3.08e+02, 5.67e+02, 5.37e+00, 1.98e+01, 1.18e+01, 3.18e+02]    []
# 3000      [1.29e+02, 4.72e+02, 4.83e+00, 1.64e+01, 1.61e+01, 2.81e+02]    [1.29e+02, 4.72e+02, 4.83e+00, 1.64e+01, 1.61e+01, 2.81e+02]    []
# 4000      [5.02e+01, 2.82e+02, 1.50e+00, 5.38e+00, 1.94e+01, 1.65e+02]    [5.02e+01, 2.82e+02, 1.50e+00, 5.38e+00, 1.94e+01, 1.65e+02]    []
# 5000      [4.54e+01, 7.02e+01, 4.69e-01, 1.45e+00, 1.22e+01, 5.28e+01]    [4.54e+01, 7.02e+01, 4.69e-01, 1.45e+00, 1.22e+01, 5.28e+01]    []
# 6000      [3.08e+01, 3.57e+01, 2.20e-01, 2.86e-01, 4.70e-01, 1.54e-01]    [3.08e+01, 3.57e+01, 2.20e-01, 2.86e-01, 4.70e-01, 1.54e-01]    []
# 7000      [9.50e+00, 1.70e+01, 1.81e-08, 2.62e-03, 6.49e-02, 2.39e-01]    [9.50e+00, 1.70e+01, 1.81e-08, 2.62e-03, 6.49e-02, 2.39e-01]    []
# 8000      [3.02e+00, 5.93e+00, 2.16e-02, 5.32e-02, 4.60e-02, 2.76e-02]    [3.02e+00, 5.93e+00, 2.16e-02, 5.32e-02, 4.60e-02, 2.76e-02]    []
# 9000      [4.48e+00, 4.09e+00, 2.99e-03, 6.86e-04, 1.52e-01, 2.81e-02]    [4.48e+00, 4.09e+00, 2.99e-03, 6.86e-04, 1.52e-01, 2.81e-02]    []
# 10000     [2.41e+00, 2.61e+00, 5.83e-03, 4.23e-03, 1.32e-01, 2.35e-02]    [2.41e+00, 2.61e+00, 5.83e-03, 4.23e-03, 1.32e-01, 2.35e-02]    []
#
# Best model at step 10000:
#   train loss: 5.19e+00
#   test loss: 5.19e+00
#   test metric: []
#
# 'train' took 42.152399 s
#
# Compiling model...
# 'compile' took 3.043043 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [2.41e-03, 2.61e-03, 5.83e-07, 4.23e-07, 1.32e-03, 2.35e-04]    [2.41e-03, 2.61e-03, 5.83e-07, 4.23e-07, 1.32e-03, 2.35e-04]    []
# 10017     [2.41e-03, 2.61e-03, 5.83e-07, 4.23e-07, 1.32e-03, 2.35e-04]    [2.41e-03, 2.61e-03, 5.83e-07, 4.23e-07, 1.32e-03, 2.35e-04]    []
#
# Best model at step 10000:
#   train loss: 6.58e-03
#   test loss: 6.58e-03
#   test metric: []
#
# 'train' took 21.358412 s
#
#
# Training relation_6_b with Bi=<function relation_dict.<locals>.<lambda> at 0x79566aa2c040>_k=50
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.064911 s
#
# 'compile' took 3.957925 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 0         [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    [1.24e+05, 1.02e+05, 9.74e-04, 2.83e-01, 7.67e-07, 1.93e-03]    []
# 1000      [3.56e+02, 5.75e+02, 1.04e+01, 2.97e+01, 2.34e+01, 3.26e+02]    [3.56e+02, 5.75e+02, 1.04e+01, 2.97e+01, 2.34e+01, 3.26e+02]    []
# 2000      [2.72e+02, 5.48e+02, 6.35e+00, 2.32e+01, 1.27e+01, 2.87e+02]    [2.72e+02, 5.48e+02, 6.35e+00, 2.32e+01, 1.27e+01, 2.87e+02]    []
# 3000      [5.03e+02, 5.65e+02, 1.47e+00, 2.72e+01, 1.39e+01, 2.66e+02]    [5.03e+02, 5.65e+02, 1.47e+00, 2.72e+01, 1.39e+01, 2.66e+02]    []
# 4000      [5.09e+01, 3.38e+02, 1.51e+00, 3.40e+00, 1.54e+01, 1.58e+02]    [5.09e+01, 3.38e+02, 1.51e+00, 3.40e+00, 1.54e+01, 1.58e+02]    []
# 5000      [5.68e+01, 6.68e+01, 2.95e-01, 9.14e-01, 1.57e+01, 6.36e+01]    [5.68e+01, 6.68e+01, 2.95e-01, 9.14e-01, 1.57e+01, 6.36e+01]    []
# 6000      [2.02e+01, 1.39e+01, 6.23e-03, 3.65e-03, 2.30e-01, 2.49e-04]    [2.02e+01, 1.39e+01, 6.23e-03, 3.65e-03, 2.30e-01, 2.49e-04]    []
# 7000      [4.80e+00, 3.84e+00, 7.77e-05, 1.94e-03, 3.58e-02, 5.57e-05]    [4.80e+00, 3.84e+00, 7.77e-05, 1.94e-03, 3.58e-02, 5.57e-05]    []
# 8000      [4.93e+00, 3.53e+00, 2.27e-03, 2.48e-04, 7.32e-02, 7.47e-02]    [4.93e+00, 3.53e+00, 2.27e-03, 2.48e-04, 7.32e-02, 7.47e-02]    []
# 9000      [2.22e+01, 9.13e+00, 9.86e-03, 9.05e-02, 7.56e-02, 6.66e-02]    [2.22e+01, 9.13e+00, 9.86e-03, 9.05e-02, 7.56e-02, 6.66e-02]    []
# 10000     [6.81e+00, 4.05e+00, 2.53e-02, 3.51e-05, 1.39e-01, 1.51e-02]    [6.81e+00, 4.05e+00, 2.53e-02, 3.51e-05, 1.39e-01, 1.51e-02]    []
#
# Best model at step 8000:
#   train loss: 8.62e+00
#   test loss: 8.62e+00
#   test metric: []
#
# 'train' took 42.805713 s
#
# Compiling model...
# 'compile' took 3.709235 s
#
# Training model...
#
# Step      Train loss                                                      Test loss                                                       Test metric
# 10000     [6.81e-03, 4.05e-03, 2.53e-06, 3.51e-09, 1.39e-03, 1.51e-04]    [6.81e-03, 4.05e-03, 2.53e-06, 3.51e-09, 1.39e-03, 1.51e-04]    []
# 10018     [6.81e-03, 4.05e-03, 2.53e-06, 3.51e-09, 1.39e-03, 1.51e-04]    [6.81e-03, 4.05e-03, 2.53e-06, 3.51e-09, 1.39e-03, 1.51e-04]    []
#
# Best model at step 10000:
#   train loss: 1.24e-02
#   test loss: 1.24e-02
#   test metric: []
#
# 'train' took 22.171475 s
